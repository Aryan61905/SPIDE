# %%
import pandas as pd
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
df = pd.read_csv("/Users/roy/Desktop/SPIDE/Phase2/csvs/OverallPlayerStats.csv")

# %%
df.columns

df = df[df.PTS != "PTS"]
df["TRB"] = df["TRB"].astype(float)
df["PTS"] = df["PTS"].astype(float)
df["AST"] = df["AST"].astype(float)

df["COMBO"] = (df["PTS"])+(df["AST"])+(df["TRB"])
df = df.sort_values(by=["COMBO"],ascending=False)
PTS_df = df.sort_values(by=["3P"],ascending=False)


df.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'COMBO'],
#       dtype='object')

# %%
grouped_teams = df.groupby('Tm')
columns_to_include = ['Tm' ,'Player','G','MP','3P','3PA','TRB', 'AST','PTS', 'COMBO']
# Create separate DataFrames for each team
team_dataframes = {}
for team_name, group_data in grouped_teams:
    team_dataframes[team_name] = group_data.loc[:,columns_to_include]

# Access each team's DataFrame using the team name

# %%
df.loc[:,columns_to_include].head(30)
# Out:
#       Tm                   Player   G    MP   3P   3PA   TRB   AST   PTS  \
# 151  PHI              Joel Embiid  33  34.2  1.2   3.2  11.4   5.8  36.0
# 138  DAL              Luka Dončić  40  37.5  3.9  10.3   8.6   9.6  34.7
# 11   MIL    Giannis Antetokounmpo  45  35.1  0.4   1.7  11.7   6.2  31.0
# 270  DEN             Nikola Jokić  47  33.7  1.0   2.9  12.1   9.0  26.3
# 181  OKC  Shai Gilgeous-Alexander  46  34.3  1.2   3.4   5.6   6.4  31.3
# 472  SAC         Domantas Sabonis  45  35.4  0.5   1.1  13.0   7.9  19.9
# 600  ATL               Trae Young  41  36.4  3.2   8.9   2.9  10.8  27.0
# 126  LAL            Anthony Davis  46  35.9  0.4   1.2  12.1   3.7  24.9
# 62   PHO             Devin Booker  38  36.2  2.3   5.9   4.9   7.3  28.4
# 145  PHO             Kevin Durant  40  37.3  2.3   5.0   6.4   5.7  28.3
# 202  IND        Tyrese Haliburton  34  33.4  3.4   8.4   4.1  12.6  23.6
# 257  LAL             LeBron James  43  34.7  2.2   5.4   7.4   7.7  25.0
# 518  BOS             Jayson Tatum  44  35.8  3.0   8.2   8.5   4.4  26.9
# 367  CLE         Donovan Mitchell  35  35.6  3.1   9.1   5.5   6.3  27.7
# 375  MEM                Ja Morant   9  35.3  1.6   5.7   5.6   8.1  25.1
# 448  NYK            Julius Randle  46  35.4  1.7   5.3   9.2   5.0  24.0
# 164  SAC             De'Aaron Fox  39  35.6  3.1   7.9   4.1   5.6  27.5
# 86   NYK            Jalen Brunson  45  35.6  2.8   6.6   3.9   6.5  26.7
# 28   CHO              LaMelo Ball  22  32.3  3.2   9.0   5.1   8.0  23.9
# 124  GSW            Stephen Curry  40  33.5  4.7  11.6   4.2   5.0  27.3
# 148  MIN          Anthony Edwards  44  35.0  2.5   6.4   5.2   5.3  25.9
# 306  MIL           Damian Lillard  44  35.2  3.0   8.5   4.3   6.8  25.1
# 484  HOU           Alperen Şengün  46  32.7  0.6   2.0   9.2   5.1  21.9
# 337  PHI             Tyrese Maxey  42  37.5  3.1   8.2   3.6   6.6  25.7
# 247  DAL             Kyrie Irving  27  33.3  2.9   7.0   5.1   5.3  25.2
# 3    MIA              Bam Adebayo  37  34.9  0.0   0.3  10.5   4.2  20.7
# 30   ORL           Paolo Banchero  47  34.9  1.5   4.2   7.0   5.0  23.0
# 493  IND            Pascal Siakam   6  32.5  0.8   2.2   7.7   5.7  21.3
# 537  MIN       Karl-Anthony Towns  46  33.3  2.2   5.0   8.7   3.1  22.6
# 327  UTA          Lauri Markkanen  38  32.4  3.2   8.0   8.8   1.9  23.7
#
#      COMBO
# 151   53.2
# 138   52.9
# 11    48.9
# 270   47.4
# 181   43.3
# 472   40.8
# 600   40.7
# 126   40.7
# 62    40.6
# 145   40.4
# 202   40.3
# 257   40.1
# 518   39.8
# 367   39.5
# 375   38.8
# 448   38.2
# 164   37.2
# 86    37.1
# 28    37.0
# 124   36.5
# 148   36.4
# 306   36.2
# 484   36.2
# 337   35.9
# 247   35.6
# 3     35.4
# 30    35.0
# 493   34.7
# 537   34.4
# 327   34.4

# %%
team_dataframes["BOS"].head(5)
# Out:
#       Tm              Player   G    MP   3P  3PA  TRB  AST   PTS  COMBO
# 518  BOS        Jayson Tatum  44  35.8  3.0  8.2  8.5  4.4  26.9   39.8
# 81   BOS        Jaylen Brown  44  33.3  2.1  5.9  5.4  3.7  22.6   31.7
# 434  BOS  Kristaps Porziņģis  33  29.7  1.8  5.1  6.7  2.0  19.5   28.2
# 574  BOS       Derrick White  43  32.0  2.7  6.7  4.0  4.7  15.6   24.3
# 230  BOS        Jrue Holiday  43  33.5  2.1  4.9  6.0  4.6  13.3   23.9

# %%
team_dataframes["LAL"].head(5)
# Out:
#       Tm            Player   G    MP   3P  3PA   TRB  AST   PTS  COMBO
# 126  LAL     Anthony Davis  46  35.9  0.4  1.2  12.1  3.7  24.9   40.7
# 257  LAL      LeBron James  43  34.7  2.2  5.4   7.4  7.7  25.0   40.1
# 470  LAL  D'Angelo Russell  44  30.8  2.6  6.2   2.6  6.1  17.3   26.0
# 450  LAL     Austin Reaves  48  30.5  1.5  4.5   4.0  5.2  14.9   24.1
# 201  LAL     Rui Hachimura  34  22.8  1.1  2.9   3.5  1.1  11.2   15.8

# %%
import sqlite3
conn = sqlite3.connect("/Users/roy/Desktop/SPIDE/Phase2/DataBase/NBA_Player_Database.db")
cursor = conn.cursor()

# %%
query = 'SELECT * FROM BoxScores where Player = "Domantas Sabonis"'
df = pd.read_sql_query(query, conn)
df
# Out:
#      boxscores_id               BoxScore_ID            Player     MP   FG  \
# 0            2327   202310250UTAVSSAC_G SAC  Domantas Sabonis  32:08  8.0
# 1            2343  202310250UTAVSSAC_Q1 SAC  Domantas Sabonis   8:52  1.0
# 2            2359  202310250UTAVSSAC_Q2 SAC  Domantas Sabonis   7:29  3.0
# 3            2375  202310250UTAVSSAC_H1 SAC  Domantas Sabonis  16:21  4.0
# 4            2391  202310250UTAVSSAC_Q3 SAC  Domantas Sabonis   9:01  2.0
# ..            ...                       ...               ...    ...  ...
# 280        120236  202401160PHOVSSAC_Q2 SAC  Domantas Sabonis   6:57  1.0
# 281        120252  202401160PHOVSSAC_H1 SAC  Domantas Sabonis  18:57  5.0
# 282        120268  202401160PHOVSSAC_Q3 SAC  Domantas Sabonis  10:52  2.0
# 283        120284  202401160PHOVSSAC_Q4 SAC  Domantas Sabonis   9:30  2.0
# 284        120300  202401160PHOVSSAC_H2 SAC  Domantas Sabonis  20:22  4.0
#
#       FGA    FG%   3P  3PA  3P%  ...   PF   PTS  +/-  BoxScore_Type  \
# 0    14.0  0.571  1.0  2.0  0.5  ...  3.0  22.0   +5              G
# 1     1.0  1.000  0.0  0.0  NaN  ...  0.0   2.0   +3             Q1
# 2     6.0  0.500  1.0  2.0  0.5  ...  0.0   7.0   +4             Q2
# 3     7.0  0.571  1.0  2.0  0.5  ...  0.0   9.0   +7             H1
# 4     4.0  0.500  0.0  0.0  NaN  ...  1.0   7.0   -1             Q3
# ..    ...    ...  ...  ...  ...  ...  ...   ...  ...            ...
# 280   2.0  0.500  0.0  0.0  NaN  ...  1.0   3.0   +3             Q2
# 281   7.0  0.714  0.0  0.0  NaN  ...  1.0  11.0  +15             H1
# 282   2.0  1.000  1.0  1.0  1.0  ...  0.0   5.0   -4             Q3
# 283   2.0  1.000  0.0  0.0  NaN  ...  1.0   5.0  -13             Q4
# 284   4.0  1.000  1.0  1.0  1.0  ...  1.0  10.0  -17             H2
#
#                  Token  Home  Away      Date  Team  Opponent
# 0    202310250UTAVSSAC   UTA   SAC  20231025   SAC       UTA
# 1    202310250UTAVSSAC   UTA   SAC  20231025   SAC       UTA
# 2    202310250UTAVSSAC   UTA   SAC  20231025   SAC       UTA
# 3    202310250UTAVSSAC   UTA   SAC  20231025   SAC       UTA
# 4    202310250UTAVSSAC   UTA   SAC  20231025   SAC       UTA
# ..                 ...   ...   ...       ...   ...       ...
# 280  202401160PHOVSSAC   PHO   SAC  20240116   SAC       PHO
# 281  202401160PHOVSSAC   PHO   SAC  20240116   SAC       PHO
# 282  202401160PHOVSSAC   PHO   SAC  20240116   SAC       PHO
# 283  202401160PHOVSSAC   PHO   SAC  20240116   SAC       PHO
# 284  202401160PHOVSSAC   PHO   SAC  20240116   SAC       PHO
#
# [285 rows x 30 columns]
