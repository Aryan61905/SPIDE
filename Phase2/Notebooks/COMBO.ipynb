# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/roy/Desktop/SPIDE/Phase2/csvs/OverallPlayerStats.csv")

# %%
df.columns

df = df[df.PTS != "PTS"]
df["TRB"] = df["TRB"].astype(float)
df["PTS"] = df["PTS"].astype(float)
df["AST"] = df["AST"].astype(float)

df["COMBO"] = (df["PTS"])+(df["AST"])+(df["TRB"])
df = df.sort_values(by=["COMBO"],ascending=False)
PTS_df = df.sort_values(by=["3P"],ascending=False)


df.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'COMBO'],
#       dtype='object')

# %%
grouped_teams = df.groupby('Tm')
columns_to_include = ['Tm' ,'Player','G','MP','3P','3PA','TRB', 'AST','PTS', 'COMBO']
# Create separate DataFrames for each team
team_dataframes = {}
for team_name, group_data in grouped_teams:
    team_dataframes[team_name] = group_data.loc[:,columns_to_include]

# Access each team's DataFrame using the team name

# %%
df.loc[:,columns_to_include].head(30)
x=df["Player"][0:31]
print(str(list(x)).replace("'",''))
# Out:
# [Luka Dončić, Joel Embiid, Giannis Antetokounmpo, Nikola Jokić, Shai Gilgeous-Alexander, Domantas Sabonis, Anthony Davis, Kevin Durant, Jayson Tatum, Donovan Mitchell, Trae Young, LeBron James, Devin Booker, Ja Morant, Julius Randle, Jalen Brunson, Tyrese Haliburton, Stephen Curry, LaMelo Ball, Anthony Edwards, "DeAaron Fox", Kyrie Irving, Tyrese Maxey, Damian Lillard, Alperen Şengün, Bam Adebayo, Paolo Banchero, Desmond Bane, Scottie Barnes, Karl-Anthony Towns, Victor Wembanyama]

# %%
team_dataframes["PHI"].head(20)
# Out:
#       Tm             Player   G    MP   3P  3PA   TRB  AST   PTS  COMBO
# 176  PHI        Joel Embiid  34  34.0  1.2  3.3  11.3  5.7  35.3   52.3
# 398  PHI       Tyrese Maxey  51  37.3  3.0  8.0   3.8  6.4  25.8   36.0
# 272  PHI        Buddy Hield   6  36.8  4.2  9.2   3.8  6.2  19.3   29.3
# 255  PHI      Tobias Harris  50  33.8  1.2  3.3   6.0  3.4  17.5   26.9
# 375  PHI         Kyle Lowry   1  25.0  1.0  2.0   4.0  5.0  11.0   20.0
# 484  PHI    Kelly Oubre Jr.  44  29.1  1.4  4.5   4.5  1.1  14.0   19.6
# 413  PHI  De'Anthony Melton  34  28.7  2.1  5.8   3.9  3.1  11.7   18.7
# 488  PHI      Cameron Payne   6  22.0  1.5  4.3   1.7  3.5  11.0   16.2
# 528  PHI          Paul Reed  56  18.0  0.2  0.6   5.5  1.2   6.5   13.2
# 61   PHI   Patrick Beverley  47  19.6  0.7  2.3   3.1  3.1   6.3   12.5
# 50   PHI      Nicolas Batum  33  24.5  1.3  2.7   3.8  2.2   5.6   11.6
# 443  PHI      Marcus Morris  37  17.2  1.0  2.4   2.9  0.7   6.7   10.3
# 140  PHI   Robert Covington  26  16.1  0.7  1.8   3.4  0.7   4.5    8.6
# 137  PHI   Ricky Council IV  16   9.3  0.3  1.0   2.0  0.3   6.1    8.4
# 31   PHI           Mo Bamba  34  10.6  0.4  0.9   3.6  0.7   3.9    8.2
# 591  PHI     Jaden Springer  32  11.8  0.3  1.2   1.8  1.1   4.0    6.9
# 627  PHI        P.J. Tucker   3  22.0  0.7  1.7   4.7  0.0   2.0    6.7
# 286  PHI   Danuel House Jr.  34  15.0  0.4  1.5   1.7  0.8   4.2    6.7
# 394  PHI          KJ Martin  40  11.3  0.1  0.4   1.9  0.8   3.5    6.2
# 587  PHI   Terquavion Smith  12   5.8  1.0  2.6   0.2  0.8   3.8    4.8

# %%
team_dataframes["POR"].head(5)
# Out:
#       Tm           Player   G    MP   3P  3PA   TRB  AST   PTS  COMBO
# 575  POR  Anfernee Simons  32  33.6  3.4  8.7   3.5  5.4  22.9   31.8
# 230  POR     Jerami Grant  48  34.0  2.1  5.2   3.7  2.7  21.8   28.2
# 21   POR    Deandre Ayton  38  31.8  0.0  0.0  10.4  1.7  14.1   26.2
# 88   POR  Malcolm Brogdon  39  28.7  2.1  5.1   3.8  5.5  15.7   25.0
# 569  POR   Shaedon Sharpe  32  33.1  1.9  5.6   5.0  2.9  15.9   23.8

# %%
import sqlite3
conn = sqlite3.connect("/Users/roy/Desktop/SPIDE/Phase2/DataBase/NBA_Player_Database.db")
cursor = conn.cursor()

# %%
query = 'SELECT * FROM BoxScores where Player = "Domantas Sabonis"'
df = pd.read_sql_query(query, conn)
df
# Out:
#      boxscores_id               BoxScore_ID            Player     MP   FG  \
# 0            2327   202310250UTAVSSAC_G SAC  Domantas Sabonis  32:08  8.0
# 1            2343  202310250UTAVSSAC_Q1 SAC  Domantas Sabonis   8:52  1.0
# 2            2359  202310250UTAVSSAC_Q2 SAC  Domantas Sabonis   7:29  3.0
# 3            2375  202310250UTAVSSAC_H1 SAC  Domantas Sabonis  16:21  4.0
# 4            2391  202310250UTAVSSAC_Q3 SAC  Domantas Sabonis   9:01  2.0
# ..            ...                       ...               ...    ...  ...
# 385        167061  202402220SACVSSAS_Q2 SAC  Domantas Sabonis   8:07  2.0
# 386        167076  202402220SACVSSAS_H1 SAC  Domantas Sabonis  14:33  6.0
# 387        167091  202402220SACVSSAS_Q3 SAC  Domantas Sabonis   9:39  1.0
# 388        167106  202402220SACVSSAS_Q4 SAC  Domantas Sabonis   8:50  4.0
# 389        167121  202402220SACVSSAS_H2 SAC  Domantas Sabonis  18:29  5.0
#
#       FGA    FG%   3P  3PA  3P%  ...   PF   PTS  +/-  BoxScore_Type  \
# 0    14.0  0.571  1.0  2.0  0.5  ...  3.0  22.0   +5              G
# 1     1.0  1.000  0.0  0.0  NaN  ...  0.0   2.0   +3             Q1
# 2     6.0  0.500  1.0  2.0  0.5  ...  0.0   7.0   +4             Q2
# 3     7.0  0.571  1.0  2.0  0.5  ...  0.0   9.0   +7             H1
# 4     4.0  0.500  0.0  0.0  NaN  ...  1.0   7.0   -1             Q3
# ..    ...    ...  ...  ...  ...  ...  ...   ...  ...            ...
# 385   3.0  0.667  0.0  0.0  NaN  ...  0.0   4.0   +5             Q2
# 386   7.0  0.857  0.0  0.0  NaN  ...  0.0  12.0  +13             H1
# 387   2.0  0.500  0.0  0.0  NaN  ...  1.0   2.0    0             Q3
# 388   6.0  0.667  0.0  0.0  NaN  ...  0.0   8.0   +2             Q4
# 389   8.0  0.625  0.0  0.0  NaN  ...  1.0  10.0   +2             H2
#
#                  Token  Home  Away      Date  Team  Opponent
# 0    202310250UTAVSSAC   UTA   SAC  20231025   SAC       UTA
# 1    202310250UTAVSSAC   UTA   SAC  20231025   SAC       UTA
# 2    202310250UTAVSSAC   UTA   SAC  20231025   SAC       UTA
# 3    202310250UTAVSSAC   UTA   SAC  20231025   SAC       UTA
# 4    202310250UTAVSSAC   UTA   SAC  20231025   SAC       UTA
# ..                 ...   ...   ...       ...   ...       ...
# 385  202402220SACVSSAS   SAC   SAS  20240222   SAC       SAS
# 386  202402220SACVSSAS   SAC   SAS  20240222   SAC       SAS
# 387  202402220SACVSSAS   SAC   SAS  20240222   SAC       SAS
# 388  202402220SACVSSAS   SAC   SAS  20240222   SAC       SAS
# 389  202402220SACVSSAS   SAC   SAS  20240222   SAC       SAS
#
# [390 rows x 30 columns]
