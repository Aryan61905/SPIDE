# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/roy/Desktop/SPIDE/Phase2/csvs/OverallPlayerStats.csv")

# %%
df.columns

df = df[df.PTS != "PTS"]
df["TRB"] = df["TRB"].astype(float)
df["PTS"] = df["PTS"].astype(float)
df["AST"] = df["AST"].astype(float)

df["COMBO"] = (df["PTS"])+(df["AST"])+(df["TRB"])
df = df.sort_values(by=["COMBO"],ascending=False)
points_df = df.sort_values(by=["COMBO"],ascending=False)

df.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'COMBO'],
#       dtype='object')

# %%
grouped_teams = df.groupby('Tm')
columns_to_include = ['Tm' ,'Player','G','MP','3P','3PA','TRB', 'AST','PTS', 'COMBO']
# Create separate DataFrames for each team
team_dataframes = {}
for team_name, group_data in grouped_teams:
    team_dataframes[team_name] = group_data.loc[:,columns_to_include]

# Access each team's DataFrame using the team name

# %%
df.head(20)
# Out:
#       Rk                   Player Pos Age   Tm   G  GS    MP    FG   FGA  ...  \
# 151  132              Joel Embiid   C  29  PHI  31  31  34.2  11.7  21.8  ...
# 138  120              Luka Dončić  PG  24  DAL  35  35  36.8  11.4  23.5  ...
# 11    10    Giannis Antetokounmpo  PF  29  MIL  40  40  35.2  11.6  19.0  ...
# 267  239             Nikola Jokić   C  28  DEN  43  43  33.6  10.2  17.3  ...
# 181  157  Shai Gilgeous-Alexander  PG  25  OKC  41  41  34.5  11.0  20.1  ...
# 145  126             Kevin Durant  PF  35  PHO  35  35  37.0  10.3  19.4  ...
# 126  108            Anthony Davis   C  30  LAL  42  42  35.9   9.4  16.8  ...
# 593  528               Trae Young  PG  25  ATL  39  39  36.3   8.3  19.7  ...
# 465  414         Domantas Sabonis   C  27  SAC  41  41  35.2   8.1  13.2  ...
# 202  177        Tyrese Haliburton  PG  23  IND  34  34  33.4   8.4  16.9  ...
# 62    51             Devin Booker  PG  27  PHO  33  33  36.0   9.3  19.3  ...
# 256  228             LeBron James  PF  39  LAL  40  40  34.3   9.3  17.8  ...
# 511  456             Jayson Tatum  PF  25  BOS  40  40  35.8   9.0  19.3  ...
# 363  324         Donovan Mitchell  SG  27  CLE  31  31  35.6   9.6  20.9  ...
# 371  332                Ja Morant  PG  24  MEM   9   9  35.3   8.9  18.9  ...
# 443  393            Julius Randle  PF  29  NYK  43  43  35.6   8.7  18.3  ...
# 28    22              LaMelo Ball  PG  22  CHO  19  19  32.7   8.6  19.4  ...
# 164  142             De'Aaron Fox  PG  26  SAC  35  35  35.6   9.9  21.1  ...
# 86    72            Jalen Brunson  PG  27  NYK  41  41  35.8   9.3  19.6  ...
# 302  272           Damian Lillard  PG  33  MIL  39  39  35.2   7.5  17.4  ...
#
#      ORB  DRB   TRB   AST  STL  BLK  TOV   PF   PTS COMBO
# 151  2.5  8.8  11.4   5.9  1.2  1.9  3.7  2.9  35.0  52.3
# 138  0.7  7.6   8.3   9.2  1.4  0.6  3.9  1.7  33.6  51.1
# 11   2.7  8.7  11.4   6.0  1.3  1.1  3.7  2.9  31.2  48.6
# 267  3.0  8.9  11.9   9.1  1.1  1.0  2.9  2.6  26.1  47.1
# 181  0.8  4.8   5.6   6.3  2.2  0.8  2.0  2.6  31.1  43.0
# 145  0.5  5.8   6.3   5.6  0.9  1.2  3.2  1.9  29.2  41.1
# 126  3.1  9.0  12.2   3.7  1.2  2.4  2.2  2.5  24.9  40.8
# 593  0.5  2.5   3.0  10.8  1.4  0.2  4.3  2.0  26.9  40.7
# 465  3.3  9.3  12.6   8.0  0.8  0.6  3.3  3.2  20.1  40.7
# 202  0.6  3.5   4.1  12.6  1.1  0.6  2.5  1.1  23.6  40.3
# 62   0.7  4.1   4.8   7.7  0.8  0.3  2.8  3.1  27.0  39.5
# 256  0.9  6.3   7.2   7.4  1.3  0.6  3.4  1.1  24.8  39.4
# 511  0.9  7.4   8.3   4.4  1.0  0.5  2.6  2.1  26.7  39.4
# 363  1.1  4.4   5.5   5.9  1.9  0.5  2.7  2.1  27.8  39.2
# 371  0.7  4.9   5.6   8.1  0.8  0.6  3.0  2.1  25.1  38.8
# 443  2.1  7.1   9.3   4.9  0.6  0.3  3.5  2.7  24.1  38.3
# 28   1.4  3.9   5.3   7.8  1.8  0.2  3.9  3.6  25.1  38.2
# 164  0.9  3.3   4.2   5.8  1.6  0.4  2.6  2.5  27.9  37.9
# 86   0.6  3.3   3.9   6.5  1.0  0.2  2.4  2.1  26.5  36.9
# 302  0.5  3.8   4.3   6.9  1.1  0.2  2.4  1.7  25.5  36.7
#
# [20 rows x 31 columns]

# %%
team_dataframes["LAL"].head(5)
# Out:
#       Tm            Player   G    MP   3P  3PA   TRB  AST   PTS  COMBO
# 122  LAL     Anthony Davis  40  36.1  0.4  1.1  12.2  3.7  25.2   41.1
# 249  LAL      LeBron James  38  34.4  2.1  5.4   7.2  7.6  24.7   39.5
# 451  LAL  D'Angelo Russell  38  29.4  2.2  5.6   2.8  6.1  15.7   24.6
# 433  LAL     Austin Reaves  42  30.1  1.5  4.4   4.2  5.2  15.1   24.5
# 195  LAL     Rui Hachimura  28  23.1  1.1  3.0   3.6  1.0  11.6   16.2

# %%
team_dataframes["POR"].head(5)
# Out:
#       Tm           Player   G    MP   3P  3PA   TRB  AST   PTS  COMBO
# 474  POR  Anfernee Simons  19  33.0  3.3  8.5   3.5  4.9  22.9   31.3
# 185  POR     Jerami Grant  35  33.7  2.3  5.5   3.6  2.4  21.4   27.4
# 19   POR    Deandre Ayton  24  31.7  0.0  0.0  10.8  1.6  13.1   25.5
# 470  POR   Shaedon Sharpe  32  33.1  1.9  5.6   5.0  2.9  15.9   23.8
# 71   POR  Malcolm Brogdon  31  26.8  2.1  5.2   3.4  5.1  14.8   23.3

# %%
import sqlite3
conn = sqlite3.connect("/Users/roy/Desktop/SPIDE/Phase2/DataBase/NBA_Player_Database.db")
cursor = conn.cursor()

# %%
query = 'SELECT * FROM BoxScores where Player = "Domantas Sabonis"'
df = pd.read_sql_query(query, conn)
df
# Out:
#      boxscores_id               BoxScore_ID            Player     MP   FG  \
# 0            2327   202310250UTAVSSAC_G SAC  Domantas Sabonis  32:08  8.0
# 1            2343  202310250UTAVSSAC_Q1 SAC  Domantas Sabonis   8:52  1.0
# 2            2359  202310250UTAVSSAC_Q2 SAC  Domantas Sabonis   7:29  3.0
# 3            2375  202310250UTAVSSAC_H1 SAC  Domantas Sabonis  16:21  4.0
# 4            2391  202310250UTAVSSAC_Q3 SAC  Domantas Sabonis   9:01  2.0
# ..            ...                       ...               ...    ...  ...
# 280        120236  202401160PHOVSSAC_Q2 SAC  Domantas Sabonis   6:57  1.0
# 281        120252  202401160PHOVSSAC_H1 SAC  Domantas Sabonis  18:57  5.0
# 282        120268  202401160PHOVSSAC_Q3 SAC  Domantas Sabonis  10:52  2.0
# 283        120284  202401160PHOVSSAC_Q4 SAC  Domantas Sabonis   9:30  2.0
# 284        120300  202401160PHOVSSAC_H2 SAC  Domantas Sabonis  20:22  4.0
#
#       FGA    FG%   3P  3PA  3P%  ...   PF   PTS  +/-  BoxScore_Type  \
# 0    14.0  0.571  1.0  2.0  0.5  ...  3.0  22.0   +5              G
# 1     1.0  1.000  0.0  0.0  NaN  ...  0.0   2.0   +3             Q1
# 2     6.0  0.500  1.0  2.0  0.5  ...  0.0   7.0   +4             Q2
# 3     7.0  0.571  1.0  2.0  0.5  ...  0.0   9.0   +7             H1
# 4     4.0  0.500  0.0  0.0  NaN  ...  1.0   7.0   -1             Q3
# ..    ...    ...  ...  ...  ...  ...  ...   ...  ...            ...
# 280   2.0  0.500  0.0  0.0  NaN  ...  1.0   3.0   +3             Q2
# 281   7.0  0.714  0.0  0.0  NaN  ...  1.0  11.0  +15             H1
# 282   2.0  1.000  1.0  1.0  1.0  ...  0.0   5.0   -4             Q3
# 283   2.0  1.000  0.0  0.0  NaN  ...  1.0   5.0  -13             Q4
# 284   4.0  1.000  1.0  1.0  1.0  ...  1.0  10.0  -17             H2
#
#                  Token  Home  Away      Date  Team  Opponent
# 0    202310250UTAVSSAC   UTA   SAC  20231025   SAC       UTA
# 1    202310250UTAVSSAC   UTA   SAC  20231025   SAC       UTA
# 2    202310250UTAVSSAC   UTA   SAC  20231025   SAC       UTA
# 3    202310250UTAVSSAC   UTA   SAC  20231025   SAC       UTA
# 4    202310250UTAVSSAC   UTA   SAC  20231025   SAC       UTA
# ..                 ...   ...   ...       ...   ...       ...
# 280  202401160PHOVSSAC   PHO   SAC  20240116   SAC       PHO
# 281  202401160PHOVSSAC   PHO   SAC  20240116   SAC       PHO
# 282  202401160PHOVSSAC   PHO   SAC  20240116   SAC       PHO
# 283  202401160PHOVSSAC   PHO   SAC  20240116   SAC       PHO
# 284  202401160PHOVSSAC   PHO   SAC  20240116   SAC       PHO
#
# [285 rows x 30 columns]
